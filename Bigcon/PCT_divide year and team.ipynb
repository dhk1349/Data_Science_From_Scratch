# %%
import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
# from tensorflow.keras.utils import np_utils
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras import layers 
import tensorflow.keras.backend as K 

from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler


import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go

from math import sqrt

# %%
lstm_train_X = pd.read_csv("PCT\\PCT_train_x.csv")
lstm_train_y = pd.read_csv("PCT\\PCT_train_y.csv")

lstm_test_X = pd.read_csv("PCT\\PCT_test_x.csv")
lstm_test_y = pd.read_csv("PCT\\PCT_test_y.csv")

# %%
team = list(lstm_train_X.T_ID.unique())
year = list(lstm_train_y.YEAR.unique())

# %%
team, year
# Out:
# (['LG', 'HH', 'NC', 'HT', 'SK', 'KT', 'WO', 'LT', 'SS', 'OB'],
#  [2016, 2017, 2018, 2019])

# %%
model_dict = dict()
hist_dict = dict()
test_pred_df = pd.DataFrame([],columns = ['YEAR','T_ID','y','y_pred','MSE','MSE_avg'])

idx = 0
for y in year:
    tmp1 = lstm_train_X[lstm_train_X["YEAR"] == y]
    tmp2 = lstm_train_y[lstm_train_y["YEAR"] == y]
    tmp3 = lstm_test_X[lstm_test_X["YEAR"] == y]
    tmp4 = lstm_test_y[lstm_test_y["YEAR"] == y]
    for t in team:
        name = '{}{}'.format(y,t)
        print(name,"=======================================")
        
        X_train = tmp1[tmp1["T_ID"] == t].drop(["T_ID","YEAR"],axis = 1)
        y_train = tmp2[tmp2["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        X_test = tmp3[tmp3["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        y_test = tmp4[tmp4["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        
        X_train_v = X_train.values
        y_train_v = y_train.values

        X_test_v = X_test.values
        y_test_v = y_test.values
        """
        X_train_t = X_train_v.reshape(X_train_v.shape[0], 2,X_train_v.shape[1]//2)
        X_test_t = X_test_v.reshape(X_test_v.shape[0], 2,X_test_v.shape[1]//2)
        """
        
        ## model
        K.clear_session() 
        
        model = Sequential()
        optimizer = Adam(lr=0.01)
        model.add(Dense(1024, input_shape = [X_train.shape[1]]))
        model.add(Dense(1024))
        model.add(Dense(1024))
        model.add(Dense(1024))
        model.add(Dense(1024))
        model.add(Dense(1)) # output = 1
        model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mae'])

       
        model.summary()
        
        early_stop = EarlyStopping(monitor='loss', mode = 'min',patience=2, verbose=1)

        hist1 = model.fit(X_train, y_train, epochs=100,
                  batch_size=1, verbose=1, callbacks=[early_stop])
        ##
        
        model_dict[name] = model
        hist_dict[name] = hist1
        
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        
        ######### MSE AVG#########
        mse_avg = mean_squared_error(y_test,[y_train.mean()[0]])
        
        
        test_pred_df.loc[idx,:] = [y,t,y_test_v.reshape(-1)[0],y_pred.reshape(-1)[0], mse,mse_avg]

        idx += 1

test_pred_df[['y','y_pred',"shift_AVG_1","shift_AVG_2",'MSE','MSE_avg']] = test_pred_df[['y','y_pred',"shift_AVG_1","shift_AVG_2",'MSE','MSE_avg']].astype(float)
# Out:
# 2016LG =======================================
# WARNING: Logging before flag parsing goes to stderr.
# W0927 20:31:43.176402 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 1591446672.4307 - mae: 21712.6680
# Epoch 2/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 695132.2741 - mae: 669.0995
# Epoch 3/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 154972.2363 - mae: 323.1057s - loss: 167501.3159 -
# Epoch 4/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 38898.8979 - mae: 162.6441
# Epoch 5/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 12595.2346 - mae: 86.9232
# Epoch 6/100
# 73/73 [==============================] - 2s 24ms/sample - loss: 2816.1404 - mae: 43.8321
# Epoch 7/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 2837.4190 - mae: 46.3712
# Epoch 8/100
# 73/73 [==============================] - 2s 24ms/sample - loss: 1293.1379 - mae: 28.6656 - loss: 756.0474 -
# Epoch 9/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 1008.3242 - mae: 24.06320s - loss: 1091.0694 - mae: 25.
# Epoch 10/100
# 73/73 [==============================] - 2s 24ms/sample - loss: 717.9939 - mae: 22.1924
# Epoch 11/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 846.9823 - mae: 23.9119
# Epoch 12/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 1052.5045 - mae: 26.5582
# W0927 20:32:03.378823 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00012: early stopping
# 2016HH =======================================
# W0927 20:32:04.149760 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 1532900627.3078 - mae: 21200.5195
# Epoch 2/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 409409.5517 - mae: 521.4417
# Epoch 3/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 93551.5159 - mae: 237.01530s - loss: 113098.548
# Epoch 4/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 28277.5361 - mae: 135.0437
# Epoch 5/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 21372.3704 - mae: 116.6781
# Epoch 6/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 43272.6299 - mae: 170.0772
# Epoch 7/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 57970.6392 - mae: 182.2440
# W0927 20:32:16.481774 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00007: early stopping
# 2016NC =======================================
# W0927 20:32:17.026318 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 2s 28ms/sample - loss: 1535803876.8081 - mae: 19894.6172
# Epoch 2/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 149829.5103 - mae: 255.0323
# Epoch 3/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 558.0577 - mae: 16.8397s - loss: 565.5628 - mae: 17.01
# Epoch 4/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 22.7746 - mae: 3.6740
# Epoch 5/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 17.9203 - mae: 3.3742
# Epoch 6/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 24.3666 - mae: 3.9101
# Epoch 7/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 16.8011 - mae: 3.3438s - loss: 17.0259 - mae: 3.37
# Epoch 8/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 19.5383 - mae: 3.5741
# Epoch 9/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 26.2420 - mae: 4.1126
# W0927 20:32:34.954761 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00009: early stopping
# 2016HT =======================================
# W0927 20:32:35.405600 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 27699305572.0632 - mae: 92839.1875
# Epoch 2/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 5272766.6796 - mae: 1807.0400s - loss: 6826202.8740 - mae: 212 - ETA: 0s - loss: 5836668.8598 - mae: 193
# Epoch 3/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 1481591.4384 - mae: 1067.5627
# Epoch 4/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 1118930.3036 - mae: 893.1013
# Epoch 5/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 669921.4560 - mae: 707.2332
# Epoch 6/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 446390.6214 - mae: 583.6850
# Epoch 7/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 298365.9495 - mae: 463.8454
# Epoch 8/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 216952.2859 - mae: 396.5971
# Epoch 9/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 141506.3301 - mae: 320.4213
# Epoch 10/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 93296.7829 - mae: 249.7087
# Epoch 11/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 70117.1640 - mae: 221.4741
# Epoch 12/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 42719.1916 - mae: 164.2905
# Epoch 13/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 30474.2967 - mae: 139.0557
# Epoch 14/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 24551.8105 - mae: 127.9137
# Epoch 15/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 18055.2437 - mae: 110.3693
# Epoch 16/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 16319.4726 - mae: 106.6373 - loss:
# Epoch 17/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 12910.9635 - mae: 95.7947
# Epoch 18/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 15138.3218 - mae: 105.7778
# Epoch 19/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 11348.0474 - mae: 89.7139
# Epoch 20/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 12112.0907 - mae: 97.2935
# Epoch 21/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 14082.7347 - mae: 96.61200s - loss: 13884.7
# W0927 20:33:02.347077 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00021: early stopping
# 2016SK =======================================
# W0927 20:33:02.891619 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 2576462395.0565 - mae: 27589.8652
# Epoch 2/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 383221.7385 - mae: 437.9738s - loss: 414212.6632 - mae: 45
# Epoch 3/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 88941.5602 - mae: 244.60200s - loss: 87164.4523 - mae: 251.424 - ETA: 0s - loss: 81510.6127
# Epoch 4/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 40469.1188 - mae: 161.4194
# Epoch 5/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 19381.1484 - mae: 112.3979
# Epoch 6/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 14388.5599 - mae: 97.0481
# Epoch 7/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 8232.5644 - mae: 71.9930
# Epoch 8/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 8862.5160 - mae: 72.99230s - loss: 9236.0185 - mae: 74.
# Epoch 9/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 10265.8967 - mae: 79.9506
# W0927 20:33:17.708503 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00009: early stopping
# 2016KT =======================================
# W0927 20:33:18.235093 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 1401918229708.4460 - mae: 543219.4375
# Epoch 2/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 20450710020.5485 - mae: 84715.7812
# Epoch 3/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 80489319.6176 - mae: 7011.90870s - loss: 124621789.
# Epoch 4/100
# 73/73 [==============================] - 2s 29ms/sample - loss: 21110877.0894 - mae: 4017.0620
# Epoch 5/100
# 73/73 [==============================] - 2s 27ms/sample - loss: 13253280.8665 - mae: 2965.1772
# Epoch 6/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 4777322.8935 - mae: 1735.9341
# Epoch 7/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 1181549.0761 - mae: 896.4203
# Epoch 8/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 775305.3596 - mae: 725.6404
# Epoch 9/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 419512.2908 - mae: 495.9919
# Epoch 10/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 333395.9828 - mae: 471.7554
# Epoch 11/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 462648.9914 - mae: 569.9876
# Epoch 12/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 419383.4747 - mae: 536.9127
# W0927 20:33:38.133620 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00012: early stopping
# 2016WO =======================================
# W0927 20:33:38.547514 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 966778905.8122 - mae: 15859.2256
# Epoch 2/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 314105.9758 - mae: 357.7108
# Epoch 3/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 7952.1974 - mae: 75.1305
# Epoch 4/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 8184.8405 - mae: 76.4906
# Epoch 5/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 4465.9121 - mae: 52.49290s - loss: 5434.4100 - mae:
# Epoch 6/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 2056.5660 - mae: 37.9031
# Epoch 7/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 994.4949 - mae: 24.7878
# Epoch 8/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 1309.3191 - mae: 28.7413
# Epoch 9/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 775.4814 - mae: 21.3967
# Epoch 10/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 436.4467 - mae: 16.5305
# Epoch 11/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 875.0974 - mae: 23.1825
# Epoch 12/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 559.6106 - mae: 19.0318
# W0927 20:33:54.518793 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00012: early stopping
# 2016LT =======================================
# W0927 20:33:55.047380 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 4614406308.5829 - mae: 33108.7969
# Epoch 2/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 1281692.9338 - mae: 1004.8227
# Epoch 3/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 670525.9137 - mae: 695.3922
# Epoch 4/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 198926.6150 - mae: 345.1768
# Epoch 5/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 329306.8224 - mae: 475.5670
# Epoch 6/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 230154.5325 - mae: 378.7559
# W0927 20:34:03.471845 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00006: early stopping
# 2016SS =======================================
# W0927 20:34:03.982479 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 15367055388.4500 - mae: 51204.2227
# Epoch 2/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 4856225.9283 - mae: 1444.9006
# Epoch 3/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 40968.2561 - mae: 155.7296
# Epoch 4/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 32310.8729 - mae: 144.9202
# Epoch 5/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 32339.6473 - mae: 147.5094
# Epoch 6/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 37316.9081 - mae: 152.16830s - loss: 53859.4520 - mae
# W0927 20:34:13.571345 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00006: early stopping
# 2016OB =======================================
# W0927 20:34:14.057047 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 23638614106.6673 - mae: 84267.1406
# Epoch 2/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 14723690.8097 - mae: 2486.6401
# Epoch 3/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 401675.9592 - mae: 532.9585
# Epoch 4/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 352266.8700 - mae: 514.6110
# Epoch 5/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 323948.2917 - mae: 455.8945
# Epoch 6/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 293856.2321 - mae: 456.4609
# Epoch 7/100
# 73/73 [==============================] - 2s 32ms/sample - loss: 322812.7811 - mae: 470.7491
# Epoch 8/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 261971.8788 - mae: 426.9777
# Epoch 9/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 218463.9627 - mae: 376.8287s - loss: 213135.62
# Epoch 10/100
# 73/73 [==============================] - 2s 28ms/sample - loss: 199544.4353 - mae: 384.0327
# Epoch 11/100
# 73/73 [==============================] - 2s 34ms/sample - loss: 236165.6971 - mae: 395.0702
# Epoch 12/100
# 73/73 [==============================] - 3s 36ms/sample - loss: 172014.3062 - mae: 347.1230
# Epoch 13/100
# 73/73 [==============================] - 2s 31ms/sample - loss: 140769.5233 - mae: 316.5539
# Epoch 14/100
# 73/73 [==============================] - 3s 42ms/sample - loss: 115366.4368 - mae: 284.6287
# Epoch 15/100
# 73/73 [==============================] - 2s 34ms/sample - loss: 110805.1413 - mae: 275.4998
# Epoch 16/100
# 73/73 [==============================] - 2s 34ms/sample - loss: 93756.0345 - mae: 244.39451s - loss: 106102.6412 - mae
# Epoch 17/100
# 73/73 [==============================] - 3s 36ms/sample - loss: 74757.1048 - mae: 226.8339
# Epoch 18/100
# 73/73 [==============================] - 2s 32ms/sample - loss: 89231.2452 - mae: 252.9246
# Epoch 19/100
# 73/73 [==============================] - 2s 27ms/sample - loss: 85658.4912 - mae: 239.4641
# W0927 20:34:56.045062 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00019: early stopping
# 2017LG =======================================
# W0927 20:34:56.602570 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 2638232307.2869 - mae: 30236.4961s - loss: 4463944
# Epoch 2/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 729799.0734 - mae: 678.2457
# Epoch 3/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 191011.7595 - mae: 368.6508
# Epoch 4/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 57790.6675 - mae: 195.4991
# Epoch 5/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 23622.2645 - mae: 124.5274
# Epoch 6/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 7106.0645 - mae: 65.4218
# Epoch 7/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 3969.3006 - mae: 48.4533
# Epoch 8/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 4546.5710 - mae: 54.1638
# Epoch 9/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 4904.0396 - mae: 59.9795
# W0927 20:35:10.908304 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00009: early stopping
# 2017HH =======================================
# Model: "sequential"
# W0927 20:35:11.214487 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 756816071.1712 - mae: 12654.6543
# Epoch 2/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 194048.2557 - mae: 338.9770
# Epoch 3/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 41177.1669 - mae: 168.3959
# Epoch 4/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 42312.4419 - mae: 171.0546
# Epoch 5/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 26065.9745 - mae: 133.2010
# Epoch 6/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 11300.6741 - mae: 84.2755 0s - loss:
# Epoch 7/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 8735.1173 - mae: 76.9027
# Epoch 8/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 6603.1650 - mae: 62.9522
# Epoch 9/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 5149.9157 - mae: 59.5008
# Epoch 10/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 5788.8524 - mae: 61.0034
# Epoch 11/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 3194.4089 - mae: 44.61470s - loss: 3396.0103 - mae: 4
# Epoch 12/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 3628.5936 - mae: 48.4605
# Epoch 13/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 6137.3700 - mae: 57.4683
# W0927 20:35:26.859638 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00013: early stopping
# 2017NC =======================================
# Model: "sequential"
# W0927 20:35:27.169857 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 3241682516.6542 - mae: 25721.9199s - loss: 3479993479.8494 - mae: 27556.
# Epoch 2/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 227469.8962 - mae: 383.6564
# Epoch 3/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 155544.2922 - mae: 323.7165
# Epoch 4/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 114459.9357 - mae: 272.4420
# Epoch 5/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 42075.4161 - mae: 168.9100
# Epoch 6/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 23424.8567 - mae: 124.4912
# Epoch 7/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 17760.0610 - mae: 108.2601
# Epoch 8/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 5392.4947 - mae: 59.4525
# Epoch 9/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 4497.8199 - mae: 53.7619
# Epoch 10/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 3710.2934 - mae: 51.89750s - loss: 2380.5993 -
# Epoch 11/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 4799.3216 - mae: 54.4978
# Epoch 12/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 10806.3157 - mae: 81.6481
# W0927 20:35:42.022081 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00012: early stopping
# 2017HT =======================================
# W0927 20:35:42.335282 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 1713346063.1174 - mae: 20674.0078s - loss: 4246886
# Epoch 2/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 414874.8957 - mae: 479.9884
# Epoch 3/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 94978.5061 - mae: 268.3265
# Epoch 4/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 69414.8980 - mae: 216.7067
# Epoch 5/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 61943.1221 - mae: 194.0601
# Epoch 6/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 44920.8240 - mae: 177.8662
# Epoch 7/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 41511.7977 - mae: 161.8558
# Epoch 8/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 23012.8665 - mae: 127.98670s - loss: 23020.0605 - mae: 130.01
# Epoch 9/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 21250.1938 - mae: 112.1669
# Epoch 10/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 26997.5545 - mae: 124.8996
# Epoch 11/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 25073.2642 - mae: 127.6735
# W0927 20:35:56.802546 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00011: early stopping
# 2017SK =======================================
# W0927 20:35:57.183526 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 1506160134.1290 - mae: 21885.4062
# Epoch 2/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 348643.3599 - mae: 432.6145
# Epoch 3/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 69270.1610 - mae: 224.9402
# Epoch 4/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 46863.7010 - mae: 180.3077
# Epoch 5/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 37742.5399 - mae: 161.8508
# Epoch 6/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 29693.7587 - mae: 141.56661s - loss: 38072.71
# Epoch 7/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 25113.5237 - mae: 134.7922
# Epoch 8/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 16299.5017 - mae: 106.0049
# Epoch 9/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 19532.4147 - mae: 110.18480s - loss: 17340.6559 - mae: 104.5 - ETA: 0s - loss: 16966.1457 - ma
# Epoch 10/100
# 73/73 [==============================] - 2s 28ms/sample - loss: 13163.1759 - mae: 90.3493
# Epoch 11/100
# 73/73 [==============================] - 2s 31ms/sample - loss: 13295.3849 - mae: 98.9279
# Epoch 12/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 12831.2638 - mae: 91.6435
# Epoch 13/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 12387.5960 - mae: 89.0219
# Epoch 14/100
# 73/73 [==============================] - 2s 28ms/sample - loss: 9804.2154 - mae: 80.6130
# Epoch 15/100
# 73/73 [==============================] - 2s 27ms/sample - loss: 7421.1840 - mae: 73.5906
# Epoch 16/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 7497.1785 - mae: 71.4909
# Epoch 17/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 5758.4185 - mae: 62.5325
# Epoch 18/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 5069.7024 - mae: 59.0825
# Epoch 19/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 5390.8168 - mae: 63.7081
# Epoch 20/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 4680.5560 - mae: 53.4994
# Epoch 21/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 3564.3439 - mae: 48.4791
# Epoch 22/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 4010.6805 - mae: 50.4302
# Epoch 23/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 2480.3882 - mae: 42.0581
# Epoch 24/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 2617.7528 - mae: 42.6319
# Epoch 25/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 3338.2011 - mae: 47.5908
# W0927 20:36:35.646647 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00025: early stopping
# 2017KT =======================================
# W0927 20:36:36.113396 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 5180520330.6768 - mae: 39809.0664
# Epoch 2/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 3134354.2942 - mae: 1151.9182
# Epoch 3/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 5308.3262 - mae: 54.5761
# Epoch 4/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 945.9064 - mae: 25.2970
# Epoch 5/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 969.9029 - mae: 24.8653
# Epoch 6/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 958.5956 - mae: 24.2721
# W0927 20:36:43.316132 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00006: early stopping
# 2017WO =======================================
# W0927 20:36:43.588436 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# ...
# Epoch 5/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 53085.5090 - mae: 187.8392
# Epoch 6/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 33884.8943 - mae: 153.54131s - loss: 33580.62
# Epoch 7/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 20574.4630 - mae: 117.2735
# Epoch 8/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 14304.9319 - mae: 102.1352
# Epoch 9/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 9278.5201 - mae: 84.20010s - loss: 9814.3344 - mae: 86.48
# Epoch 10/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 6097.0411 - mae: 67.1765
# Epoch 11/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 4512.9074 - mae: 59.9911
# Epoch 12/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 3359.5046 - mae: 45.2302
# Epoch 13/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 2920.1275 - mae: 44.6486
# Epoch 14/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 2379.8556 - mae: 40.6670
# Epoch 15/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 1847.2574 - mae: 35.70740s - loss: 2409.263
# Epoch 16/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 1643.4294 - mae: 33.1987
# Epoch 17/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 1296.2851 - mae: 29.0919
# Epoch 18/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 1190.8237 - mae: 27.7334
# Epoch 19/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 1104.8820 - mae: 26.6027
# Epoch 20/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 1205.2933 - mae: 27.6498
# Epoch 21/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 878.1741 - mae: 23.9682
# Epoch 22/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 887.0910 - mae: 24.2343
# Epoch 23/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 755.9745 - mae: 20.8701
# Epoch 24/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 556.3126 - mae: 18.9388
# Epoch 25/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 601.0776 - mae: 19.1053
# Epoch 26/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 698.5336 - mae: 22.0913
# W0927 20:43:10.312357 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00026: early stopping
# 2019WO =======================================
# W0927 20:43:10.650451 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 2176655028.9155 - mae: 21146.8594
# Epoch 2/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 277902.2989 - mae: 397.2195
# Epoch 3/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 23537.9375 - mae: 129.2432
# Epoch 4/100
# 73/73 [==============================] - ETA: 0s - loss: 8757.2517 - mae: 78.506 - 2s 21ms/sample - loss: 8519.1854 - mae: 76.5435
# Epoch 5/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 4596.9472 - mae: 55.6061
# Epoch 6/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 4550.5664 - mae: 53.59761s - loss: 3872.
# Epoch 7/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 4321.2634 - mae: 55.0985
# Epoch 8/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 2702.2463 - mae: 41.1366
# Epoch 9/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 1645.2395 - mae: 33.89450s - loss: 1878.1771 - ma
# Epoch 10/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 1793.5035 - mae: 34.4848
# Epoch 11/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 1540.4730 - mae: 31.10851s - loss: 308
# Epoch 12/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 1060.4039 - mae: 26.79320s - loss: 1218.591
# Epoch 13/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 1516.5925 - mae: 31.4509
# Epoch 14/100
# 73/73 [==============================] - 2s 23ms/sample - loss: 761.5336 - mae: 23.0249
# Epoch 15/100
# 73/73 [==============================] - 2s 24ms/sample - loss: 1115.4829 - mae: 28.62460s - loss: 1157.2708 - mae: 29.3
# Epoch 16/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 524.1654 - mae: 18.5995
# Epoch 17/100
# 73/73 [==============================] - 2s 26ms/sample - loss: 488.1069 - mae: 16.9915
# Epoch 18/100
# 73/73 [==============================] - 2s 25ms/sample - loss: 629.5763 - mae: 20.1526
# Epoch 19/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 1255.4833 - mae: 29.2143
# W0927 20:43:41.637594 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00019: early stopping
# 2019LT =======================================
# W0927 20:43:42.204080 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 2s 33ms/sample - loss: 927256817.6608 - mae: 15552.4229
# Epoch 2/100
# 73/73 [==============================] - 2s 30ms/sample - loss: 180031.7517 - mae: 249.9268
# Epoch 3/100
# 73/73 [==============================] - 2s 27ms/sample - loss: 7150.4419 - mae: 68.2512
# Epoch 4/100
# 73/73 [==============================] - 2s 30ms/sample - loss: 8018.5338 - mae: 71.87090s - loss: 6229.6448 -
# Epoch 5/100
# 73/73 [==============================] - 2s 33ms/sample - loss: 8078.7411 - mae: 71.3469
# W0927 20:43:54.708637 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00005: early stopping
# 2019SS =======================================
# W0927 20:43:55.599252 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 3s 47ms/sample - loss: 844841965.4757 - mae: 14700.7656
# Epoch 2/100
# 73/73 [==============================] - 2s 34ms/sample - loss: 183477.1551 - mae: 333.7325
# Epoch 3/100
# 73/73 [==============================] - 3s 38ms/sample - loss: 55063.6225 - mae: 190.3886
# Epoch 4/100
# 73/73 [==============================] - 3s 42ms/sample - loss: 22589.0325 - mae: 125.0337
# Epoch 5/100
# 73/73 [==============================] - 2s 31ms/sample - loss: 13086.7983 - mae: 94.0805
# Epoch 6/100
# 73/73 [==============================] - 2s 30ms/sample - loss: 17833.5729 - mae: 114.7798
# Epoch 7/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 13387.8598 - mae: 90.6872
# W0927 20:44:14.893639 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00007: early stopping
# 2019OB =======================================
# W0927 20:44:15.352453 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              59392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,258,817
# Trainable params: 4,258,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 1786246735.9659 - mae: 22378.6738s - loss: 3408331
# Epoch 2/100
# 73/73 [==============================] - 2s 27ms/sample - loss: 314038.8767 - mae: 366.5737
# Epoch 3/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 70647.7900 - mae: 218.0590
# Epoch 4/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 55254.4064 - mae: 192.29660s - loss: 53955.4461 - mae:
# Epoch 5/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 47921.7475 - mae: 179.0447
# Epoch 6/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 48271.5577 - mae: 178.2107
# Epoch 7/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 29428.8798 - mae: 145.3077
# Epoch 8/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 27232.9985 - mae: 137.7237
# Epoch 9/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 24795.5447 - mae: 132.3961
# Epoch 10/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 14051.1552 - mae: 93.0036
# Epoch 11/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 17872.0615 - mae: 111.2009
# Epoch 12/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 9833.6626 - mae: 83.3649
# Epoch 13/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 8612.9194 - mae: 75.9017
# Epoch 14/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 8803.8840 - mae: 74.0031
# Epoch 15/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 8949.7887 - mae: 78.6391
# W0927 20:44:36.332367 18632 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00015: early stopping
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-ba99eb9a068e> in <module>
#      64         idx += 1
#      65
# ---> 66 test_pred_df[['y','y_pred',"shift_AVG_1","shift_AVG_2",'MSE','MSE_avg']] = test_pred_df[['y','y_pred',"shift_AVG_1","shift_AVG_2",'MSE','MSE_avg']].astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['shift_AVG_2', 'shift_AVG_1'] not in index"

# %%
test_pred_df
# Out:
#     YEAR T_ID         y   y_pred      MSE      MSE_avg
# 0   2016   LG  0.608696   2.6844  4.30855    0.0198898
# 1   2016   HH       0.5  136.048  18373.2   0.00188918
# 2   2016   NC  0.565217 -11.6467  149.131   0.00236344
# 3   2016   HT  0.458333 -110.386  12286.5   0.00177981
# 4   2016   SK  0.458333  129.364  16616.6  1.59635e-05
# 5   2016   KT  0.291667 -933.407   871794   0.00425478
# 6   2016   WO     0.375  36.8734  1332.13    0.0412888
# 7   2016   LT       0.5  104.343  10783.3    0.0023538
# 8   2016   SS       0.5   -314.1    98973   0.00601803
# 9   2016   OB  0.666667 -391.222   153577   0.00438377
# 10  2017   LG  0.434783 -136.923  18867.2   0.00258055
# 11  2017   HH  0.434783  23.5129  532.598  0.000555806
# 12  2017   NC       0.5 -178.721    32120   0.00312884
# 13  2017   HT       0.5 -81.7869  6771.14    0.0126323
# 14  2017   SK     0.625  93.5128  8628.14    0.0144864
# 15  2017   KT       0.5 -113.324    12956    0.0582925
# 16  2017   WO  0.347826 -40.4778  1666.73    0.0358436
# 17  2017   LT  0.666667  259.758  67128.3    0.0211527
# 18  2017   SS  0.391304  105.523  11052.8    0.0092804
# 19  2017   OB  0.583333   107.91  11519.1   0.00171549
# 20  2018   LG  0.416667  -57.148  3313.69   0.00635766
# 21  2018   HH       0.5   88.457  7736.44   0.00366053
# 22  2018   NC  0.416667  5.72861  28.2168  0.000312202
# 23  2018   HT  0.541667  -17.289  317.933   0.00684964
# 24  2018   SK  0.458333  24.4823  577.151   0.00524381
# 25  2018   KT  0.391304 -231.612  53825.5  0.000626987
# 26  2018   WO  0.541667 -77.3022  6059.67   0.00105848
# 27  2018   LT  0.666667  43.6408  1846.78    0.0457065
# 28  2018   SS  0.521739  211.681  44588.2   4.1283e-05
# 29  2018   OB     0.625 -222.903  49964.7   9.4152e-05
# 30  2019   LG  0.541667 -508.491   259114  2.66442e-05
# 31  2019   HH  0.583333 -32.7541  1111.38    0.0656787
# 32  2019   NC  0.565217  46.4923  2109.29    0.0124046
# 33  2019   HT       0.5  30.1468  878.931  0.000390213
# 34  2019   SK     0.375 -248.478    61928    0.0814464
# 35  2019   KT  0.541667  -73.039  5414.11  0.000219495
# 36  2019   WO  0.666667  12.9374   150.57    0.0034855
# 37  2019   LT  0.208333  52.9361  2780.21    0.0280416
# 38  2019   SS  0.416667 -250.513  62965.5  0.000980832
# 39  2019   OB  0.652174  97.3001  9340.83   0.00948275
