# %%
import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
# from tensorflow.keras.utils import np_utils
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras import layers 
import tensorflow.keras.backend as K 

from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler


import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go

from math import sqrt

# %%
lstm_train_X = pd.read_csv("ERA\\ERA_train_x.csv")
lstm_train_y = pd.read_csv("ERA\\ERA_train_y.csv")

lstm_test_X = pd.read_csv("ERA\\ERA_test_x.csv")
lstm_test_y = pd.read_csv("ERA\\ERA_test_y.csv")

# %%
team = list(lstm_train_X.T_ID.unique())
year = list(lstm_train_y.YEAR.unique())

# %%
team, year
# Out:
# (['LG', 'HH', 'NC', 'HT', 'SK', 'KT', 'WO', 'LT', 'SS', 'OB'],
#  [2016, 2017, 2018, 2019])

# %%
model_dict = dict()
hist_dict = dict()
test_pred_df = pd.DataFrame([],columns = ['YEAR','T_ID','y','y_pred','MSE','MSE_avg'])

idx = 0
for y in year:
    tmp1 = lstm_train_X[lstm_train_X["YEAR"] == y]
    tmp2 = lstm_train_y[lstm_train_y["YEAR"] == y]
    tmp3 = lstm_test_X[lstm_test_X["YEAR"] == y]
    tmp4 = lstm_test_y[lstm_test_y["YEAR"] == y]
    for t in team:
        name = '{}{}'.format(y,t)
        print(name,"=======================================")
        
        X_train = tmp1[tmp1["T_ID"] == t].drop(["T_ID","YEAR"],axis = 1)
        y_train = tmp2[tmp2["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        X_test = tmp3[tmp3["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        y_test = tmp4[tmp4["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        
        X_train_v = X_train.values
        y_train_v = y_train.values

        X_test_v = X_test.values
        y_test_v = y_test.values
        """
        X_train_t = X_train_v.reshape(X_train_v.shape[0], 2,X_train_v.shape[1]//2)
        X_test_t = X_test_v.reshape(X_test_v.shape[0], 2,X_test_v.shape[1]//2)
        """
        
        ## model
        K.clear_session() 
        
        model = Sequential()
        optimizer = Adam(lr=0.01)
        model.add(Dense(1024, input_shape = [X_train.shape[1]]))
        model.add(Dense(1024))
        model.add(Dense(1024))
        model.add(Dense(1024))
        model.add(Dense(1024))
        model.add(Dense(1)) # output = 1
        model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mae'])

       
        model.summary()
        
        early_stop = EarlyStopping(monitor='loss', mode = 'min',patience=2, verbose=1)

        hist1 = model.fit(X_train, y_train, epochs=100,
                  batch_size=1, verbose=1, callbacks=[early_stop])
        ##
        
        model_dict[name] = model
        hist_dict[name] = hist1
        
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        
        ######### MSE AVG#########
        mse_avg = mean_squared_error(y_test,[y_train.mean()[0]])
        
        
        test_pred_df.loc[idx,:] = [y,t,y_test_v.reshape(-1)[0],y_pred.reshape(-1)[0], mse,mse_avg]

        idx += 1

test_pred_df[['y','y_pred',"shift_AVG_1","shift_AVG_2",'MSE','MSE_avg']] = test_pred_df[['y','y_pred',"shift_AVG_1","shift_AVG_2",'MSE','MSE_avg']].astype(float)
# Out:
# 2016LG =======================================
# WARNING: Logging before flag parsing goes to stderr.
# W0927 20:11:53.934772 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)
100
# 73/73 [==============================] - 1s 16ms/sample - loss: 4144.3108 - mae: 52.9916
# Epoch 11/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 2896.4048 - mae: 45.2823
# Epoch 12/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 2282.6879 - mae: 40.6320
# Epoch 13/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 2646.3538 - mae: 44.3264
# Epoch 14/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 2071.6544 - mae: 38.7766
# Epoch 15/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 2487.9987 - mae: 38.60600s - loss: 1986.9778 - mae: 34
# Epoch 16/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 2088.2584 - mae: 36.2531
# W0927 20:12:52.249790 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00016: early stopping
# 2016HT =======================================
# W0927 20:12:52.592874 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              47104
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,246,529
# Trainable params: 4,246,529
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 46563524005.5836 - mae: 82514.7031
# Epoch 2/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 9003173.2832 - mae: 1901.1072
# Epoch 3/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 91705.7019 - mae: 256.5587
# Epoch 4/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 92063.9900 - mae: 248.3475
# Epoch 5/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 95626.2616 - mae: 246.3833
# W0927 20:13:00.236428 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00005: early stopping
# 2016SK =======================================
# W0927 20:13:00.645334 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              47104
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,246,529
# Trainable params: 4,246,529
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 1759071876.5484 - mae: 20965.0332
# Epoch 2/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 806844.4979 - mae: 553.5553
# Epoch 3/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 55390.2372 - mae: 195.4146
# Epoch 4/100
# 73/73 [==============================] - ETA: 0s - loss: 39025.7498 - mae: 160.490 - 1s 17ms/sample - loss: 40559.8281 - mae: 163.9135
# Epoch 5/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 20030.5498 - mae: 111.9523
# Epoch 6/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 32954.2959 - mae: 147.65440s - loss: 82668.7260
# Epoch 7/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 16423.1153 - mae: 96.5815
# Epoch 8/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 12388.2778 - mae: 89.8630
# Epoch 9/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 11207.5191 - mae: 86.0185 0s - loss
# Epoch 10/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 6002.0139 - mae: 62.1760
# Epoch 11/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 6171.7948 - mae: 61.0308
# Epoch 12/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 9554.5041 - mae: 80.1693
# W0927 20:13:16.420143 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00012: early stopping
# 2016KT =======================================
# W0927 20:13:16.877914 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              47104
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,246,529
# Trainable params: 4,246,529
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 734589992.5834 - mae: 13528.3467
# Epoch 2/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 151221.1672 - mae: 268.6935
# Epoch 3/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 14103.3044 - mae: 98.7224
# Epoch 4/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 13639.9035 - mae: 96.1922
# Epoch 5/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 10041.2305 - mae: 82.2197
# Epoch 6/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 10991.5540 - mae: 84.5285
# Epoch 7/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 11970.1199 - mae: 89.1594
# W0927 20:13:27.716924 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00007: early stopping
# 2016WO =======================================
# W0927 20:13:28.236534 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              47104
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,246,529
# Trainable params: 4,246,529
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 416082314.2639 - mae: 8637.2852
# Epoch 2/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 214039.3882 - mae: 305.7019
# Epoch 3/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 8274.8052 - mae: 60.6954
# Epoch 4/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 58.9932 - mae: 5.6975
# Epoch 5/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 98.0707 - mae: 7.3167
# Epoch 6/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 38.6600 - mae: 4.3765
# Epoch 7/100
# 73/73 [==============================] - 2s 21ms/sample - loss: 28.8021 - mae: 4.3185
# Epoch 8/100
# 73/73 [==============================] - 2s 22ms/sample - loss: 21.1420 - mae: 3.6374
# Epoch 9/100
# 73/73 [==============================] - 2s 24ms/sample - loss: 31.3700 - mae: 4.6418
# Epoch 10/100
# 73/73 [==============================] - 2s 24ms/sample - loss: 26.9544 - mae: 3.8397
# W0927 20:13:44.598768 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 
100
# 73/73 [==============================] - 1s 16ms/sample - loss: 114479.3779 - mae: 269.5976
# Epoch 5/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 152631.2377 - mae: 306.9143s - loss:
# Epoch 6/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 46973.6950 - mae: 179.0078
# Epoch 7/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 29348.7241 - mae: 141.3820
# Epoch 8/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 38709.0595 - mae: 172.0588
# Epoch 9/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 12579.2170 - mae: 95.2150
# Epoch 10/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 6979.6240 - mae: 69.7733
# Epoch 11/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 7164.1211 - mae: 66.92960s - loss: 6676.0952 - ma
# Epoch 12/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 3327.3796 - mae: 47.4852
# Epoch 13/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 5825.8202 - mae: 60.4346
# Epoch 14/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 3033.1587 - mae: 44.1633
# Epoch 15/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 2207.1697 - mae: 37.9621
# Epoch 16/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 2909.8731 - mae: 44.7486
# Epoch 17/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 1998.5375 - mae: 36.3221
# Epoch 18/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 1441.2315 - mae: 32.1174
# Epoch 19/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 1153.3023 - mae: 28.0225
# Epoch 20/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 591.0844 - mae: 20.5401
# Epoch 21/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 743.6253 - mae: 22.4569
# Epoch 22/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 555.0480 - mae: 18.7403
# Epoch 23/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 487.2693 - mae: 17.4414
# Epoch 24/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 542.8046 - mae: 19.3666
# Epoch 25/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 502.6791 - mae: 18.0994s - los
# W0927 20:28:23.175277 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00025: early stopping
# 2019LT =======================================
# Model: "sequential"
# W0927 20:28:23.443559 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              47104
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,246,529
# Trainable params: 4,246,529
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 1770974525.7699 - mae: 24336.8789
# Epoch 2/100
# 73/73 [==============================] - 1s 20ms/sample - loss: 461693.8119 - mae: 524.5765
# Epoch 3/100
# 73/73 [==============================] - 1s 19ms/sample - loss: 84102.9118 - mae: 246.07000s - loss: 93283.6216 - mae: 265.
# Epoch 4/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 51654.7859 - mae: 193.6139
# Epoch 5/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 19279.4569 - mae: 115.3299
# Epoch 6/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 8511.2795 - mae: 74.7702
# Epoch 7/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 5521.7743 - mae: 58.83920s - loss: 5735.3659 - mae: 5
# Epoch 8/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 4777.8118 - mae: 54.5994
# Epoch 9/100
# 73/73 [==============================] - 1s 15ms/sample - loss: 4855.5959 - mae: 56.95350s - loss: 5364.4965 - mae
# Epoch 10/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 4541.3324 - mae: 53.7529
# Epoch 11/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 3792.3544 - mae: 51.2779
# Epoch 12/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 3692.3906 - mae: 48.2740
# Epoch 13/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 3686.9637 - mae: 47.5782
# Epoch 14/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 3806.6956 - mae: 49.9552
# Epoch 15/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 3762.0145 - mae: 51.8583
# W0927 20:28:42.346996 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00015: early stopping
# 2019SS =======================================
# W0927 20:28:42.783832 22168 training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              47104
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 4,246,529
# Trainable params: 4,246,529
# Non-trainable params: 0
# _________________________________________________________________
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 953718437.5244 - mae: 17513.16020s - loss: 1220919070.6045 - mae: 22
# Epoch 2/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 134870.1292 - mae: 260.9303
# Epoch 3/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 15419.1942 - mae: 89.1193
# Epoch 4/100
# 73/73 [==============================] - 1s 17ms/sample - loss: 12955.8596 - mae: 82.0498
# Epoch 5/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 10690.7637 - mae: 79.5217
# Epoch 6/100
# 73/73 [==============================] - 1s 18ms/sample - loss: 9596.8826 - mae: 73.8370
# Epoch 7/100
# 73/73 [==============================] - 1s 16ms/sample - loss: 10147.6896 - mae: 74.5714
# Epoch 8/100
# 73/73 [==============================] - 1s 17ms/sample - loss:
training.py:504] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Epoch 00028: early stopping
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-ba99eb9a068e> in <module>
#      64         idx += 1
#      65
# ---> 66 test_pred_df[['y','y_pred',"shift_AVG_1","shift_AVG_2",'MSE','MSE_avg']] = test_pred_df[['y','y_pred',"shift_AVG_1","shift_AVG_2",'MSE','MSE_avg']].astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['shift_AVG_2', 'shift_AVG_1'] not in index"

# %%
test_pred_df
# Out:
#     YEAR T_ID        y   y_pred          MSE     MSE_avg
# 0   2016   LG  3.64977 -16.5181      406.742     2.25378
# 1   2016   HH  5.25811 -17.8896      535.816   0.0274959
# 2   2016   NC  3.57534 -14.2021      316.036     2.08141
# 3   2016   HT  4.12083  380.035       141312     1.58214
# 4   2016   SK  5.14488 -87.4744      8578.34   0.0145698
# 5   2016   KT  6.31452  59.1235      2788.79   0.0232326
# 6   2016   WO  5.70484 -7.37659      171.124    0.343514
# 7   2016   LT  5.84929  164.623      25209.1  0.00463758
# 8   2016   SS      5.4 -4.99729      108.104    0.103031
# 9   2016   OB  4.71028  3.22168      2.21594   0.0133325
# 10  2017   LG  4.50689 -75.4489      6392.93    0.056965
# 11  2017   HH  5.50935  7.72782      4.92161    0.114832
# 12  2017   NC  6.27523  17.9203      135.607     2.75092
# 13  2017   HT   4.9814  110.305      11093.1  0.00374349
# 14  2017   SK  4.90909 -76.7971       6675.9    0.211885
# 15  2017   KT  5.59346   136.46      17126.2     0.49448
# 16  2017   WO  5.85285 -87.2694      8671.75    0.746371
# 17  2017   LT  4.07547  162.663      25149.9     1.21038
# 18  2017   SS  6.30415  78.2353      5174.09    0.418004
# 19  2017   OB  4.24528  1.70139      6.47137    0.171193
# 20  2018   LG  5.23944  2233.87  4.96679e+06   0.0872329
# 21  2018   HH   5.5514 -2.21128      60.2593     0.76231
# 22  2018   NC  6.10096 -9.79086       252.55     0.26873
# 23  2018   HT  5.55882 -16.4841       485.89  0.00710568
# 24  2018   SK  5.23817  94.4988      7967.46    0.585042
# 25  2018   KT  5.57609 -136.042      20055.7   0.0771612
# 26  2018   WO  5.63033  63.1907       3313.2     0.38301
# 27  2018   LT  4.83333   7.5798      7.54309     0.35137
# 28  2018   SS  5.35023 -79.3886      7180.66   0.0877462
# 29  2018   OB  4.75734   376.59       138259    0.116064
# 30  2019   LG  3.14646  72.5852      4821.73     1.40633
# 31  2019   HH  3.05108  86.3814      6943.94     3.86918
# 32  2019   NC  3.31726  99.3892      9229.81    0.935366
# 33  2019   HT   3.6699  116.849      12809.5    0.379769
# 34  2019   SK  3.89382 -24.3161      795.797     0.45434
# 35  2019   KT  3.43868 -74.0528      6004.92    0.964316
# 36  2019   WO  2.01429  17.0109        224.9     2.70322
# 37  2019   LT   3.6087 -35.3228      1515.66     1.41464
# 38  2019   SS  4.34928  14.4576      102.179    0.074991
# 39  2019   OB  3.51994 -58.6048      3859.48   0.0340711
